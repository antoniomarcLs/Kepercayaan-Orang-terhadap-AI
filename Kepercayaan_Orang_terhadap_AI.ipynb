# %% [markdown]
# # **Kepercayaan orang terhadap AI**

# %%
import pandas as pd

# %%
file = "/content/sample_data/Untitled Folder/V1_GlobalSuperStore2016 (1).csv"
Datafile = pd.read_csv(file)

Datafile
# Out:
#      Unnamed: 0                  Order ID        Order Date     Customer Name  \
# 0             0  CA-2014-AB10015140-41954        11-11-2014     Aaron Bergman
# 1             1    IN-2014-JR162107-41675        2014-02-05     Justin Ritter
# 2             2    IN-2014-CR127307-41929  October 17, 2014      Craig Reiter
# 3             3   ES-2014-KM1637548-41667        28-01-2014  Katherine Murray
# 4             4   SG-2014-RH9495111-41948  05 November 2014       Rick Hansen
# ..          ...                       ...               ...               ...
# 150         150   IT-2012-ZC2191048-41174        2012/09/22  Zuschuss Carroll
# 151         151   IN-2013-MB1808592-41378        14-04-2013        Mick Brown
# 152         152  CA-2012-AB10015140-40974        2012-03-06     Aaron Bergman
# 153         153    IN-2013-NC186257-41401        2013/05/07       Noah Childs
# 154         154    IN-2015-JH158207-42140       16 May 2015       John Huston
#
# ...

# %% [markdown]
# # **Business Understanding**

# %% [markdown]
# ## **Business Objective**

# %% [markdown]
# This Dataset has an information about AI Agent with their answers to users with specific questions including their confidence to answer, how much lenght word they usually use etc.

# %% [markdown]
# ## **Assess Situation**

# %% [markdown]
# This Dataset has information about 6 AI agent with 12 variations of questions, this data set has information about AI agent behaviors when answering an user question, there are some missing information in 2 of 23 column.

# %% [markdown]
# ## **Analytic Goals**
# *  Classified each AI agent with their behaviors
# *  Visualizing information so user can choose which AI agent fit their best
# *  Client know which AI agent has most suitable behaviors with them
# *  Solve the problem of some missing information

# %% [markdown]
# ## **Project Plan**
# *  Understanding data
# *  Visualizing data
# *  Advantaging data
# *  Repairing some data
